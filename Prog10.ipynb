# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras import models,layers
# Out:
# 2024-10-22 14:57:11.186663: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-10-22 14:57:11.187558: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-10-22 14:57:11.190026: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-10-22 14:57:11.198047: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-22 14:57:11.211975: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-22 14:57:11.215835: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-22 14:57:11.225584: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-22 14:57:12.105476: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
data = np.random.rand(100,1)

# %%
target = np.full((100,1),100)

# %%
data = data.reshape((100,1,1))

# %%
model = models.Sequential([layers.LSTM(units=50, activation='relu', input_shape=(None,1)),layers.Dense(units=1)])

# %%
model.compile(optimizer='adam',loss='mse')

# %%
model.fit(data,target,epochs=100,verbose=0)

# %%
predictions = model.predict(data)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step

# %%
print('Original data : \n',target.flatten())
print('Predicted data : \n',predictions.flatten())
# Out:
# Original data :
#  [100 100 100 100 100 100 100 100 100 100 100 100 100 100 100 100 100 100
#  100 100 100 100 100 100 100 100 100 100 100 100 100 100 100 100 100 100
#  100 100 100 100 100 100 100 100 100 100 100 100 100 100 100 100 100 100
#  100 100 100 100 100 100 100 100 100 100 100 100 100 100 100 100 100 100
#  100 100 100 100 100 100 100 100 100 100 100 100 100 100 100 100 100 100
#  100 100 100 100 100 100 100 100 100 100]
# Predicted data :
#  [ 4.4645505 11.534027  11.719301   8.743117   4.2020307  4.4750834
#   6.388585  11.706241  11.451106  11.160436   4.2591434  9.74503
#   7.0560493  8.961313   8.617898   6.0380545  4.451007   6.9646873
#   9.89838    7.5439987  9.754628   5.0251026 11.140561   6.0708733
#   7.5204425  9.088591   8.822776  11.306062  10.461061   4.7227535
#   9.170764   4.209907   6.742109  10.150792  11.074792   4.9413505
#   7.2082086  7.4711146 10.250365  11.651175   7.407523   8.706946
#   4.490401  10.419878  11.294799   4.9783435  5.8747234  5.688153
#   5.420138   7.317138  11.454576   9.574074   6.8576107  6.276538
#   7.501353   5.852484   5.975231   4.8451505 10.941702   9.830948
#   8.000675   5.9829836  6.9653726  5.1169205  4.999705  11.50286
#   4.549164   9.898036  10.365901   6.9423532  4.7500143  7.702509
#   5.501399   5.238644  10.010625   5.345408   9.777202  11.357793
#   7.7655563  4.7829366  9.397292   7.4173765  4.5585146  6.8553815
#   9.661248   8.681973  11.130078   6.1454844 10.17574    9.120667
#  10.458334   8.358233   4.824395   5.027461   5.6928487  4.6029663
#  10.096601   6.883002   4.532503  10.570966 ]

# %%
plt.plot(target,label='Original Data', marker='o')
plt.plot(predictions,label='Predicted Data',marker='x')
plt.title('Original data vs Predicted Data')
plt.xlabel('Sample Index')
plt.ylabel('Values')
plt.legend()
plt.show()
